# %% [markdown]
# <a href="https://colab.research.google.com/github/sharmai309/langChainLearning/blob/main/openai_begin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from openai import OpenAI

client = OpenAI(
    base_url="https://router.huggingface.co/v1",
    api_key="hf"  # your HF token
)

completion = client.chat.completions.create(
    model="meta-llama/Llama-3.3-70B-Instruct",
    messages=[{"role": "user", "content": "Tell me a joke"}]
)

print(completion.choices[0].message.content)
